# %% [markdown]
# # STEPS
# # I. Loading libraries
# # II. Loading the data (train + test)
# # III. Data Analysis
# # IV. Merge train and test data for data preprocessing (optional)
# # V. Handle errors in data (categorical and numerical)
# # VI. Feature Engineering
# # VII. Feature Transformation
# # VIII. Encode categorical features
# # IX. Split data
# # X. Target feature encoding
# # XI. Model + K Fold cross-validation
# # XII. Baggin Ensemble
# # XIII. Submiting prediction

# %% [markdown]
# # I. Loading libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # II. Loading the data (train + test)

# %%
# Train data
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
# Test data
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test.shape
# Out:
# (1459, 80)

# %% [markdown]
# # III. Data Analysis

# %%
# For Training Data
# Extract column names from the training DataFrame
train_column_list = df_train.columns
# Convert the Index object to a DataFrame
train_column_list_df = train_column_list.to_frame(index=False)
# Write the DataFrame to a CSV file
train_column_list_df.to_csv('train_column_list.txt', index=False, header=False)

# For Testing Data
# Extract column names from the testing DataFrame
test_column_list = df_test.columns
# Convert the Index object to a DataFrame
test_column_list_df = test_column_list.to_frame(index=False)
# Write the DataFrame to a CSV file
test_column_list_df.to_csv('test_column_list.txt', index=False, header=False)

# %%
plt.hist(df_train['SalePrice'], bins=100)
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.title('Histogram of Sale Price')
plt.show()

# %% [markdown]
# "right-skewed"
# Now we start to plot SalePrice(all numerical features) to search for outliers that we will note

# %%
# For Training Data
numerical_df_train = df_train.select_dtypes(include=[np.number])

# Extract numerical column names from the training DataFrame
numerical_train_features = numerical_df_train.columns

# Convert to DataFrame to use to_csv method
numerical_train_features_df = pd.DataFrame(numerical_train_features, columns=['Feature'])

# Write the DataFrame to a CSV file
numerical_train_features_df.to_csv('numerical_train_features.txt', index=False, header=False, sep='\t')

# %%
object_df_train = df_train.select_dtypes(include=[object])

# Extract object column names from the training DataFrame
object_train_features = object_df_train.columns

# Convert to DataFrame to use to_csv method
object_train_features_df = pd.DataFrame(object_train_features, columns=['Feature'])

# Write the DataFrame to a CSV file
object_train_features_df.to_csv('object_train_features.txt', index=False, header=False, sep='\t')

# %% [markdown]
# We start analysing each numericalfeature vs SalePrice plot and note the outliers

# %% [markdown]
# 1stFlrSF

# %%
numerical_df_train.query('`1stFlrSF` > 4000') # 1299
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 1298  1299          60        313.0    63887           10            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 1298       2008          2008       796.0        5644  ...         214
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 1298          292              0          0            0       480        0
#
#       MoSold  YrSold  SalePrice
# 1298       1    2008     160000
#
# [1 rows x 38 columns]

# %% [markdown]
# BedroomAbvGr

# %%
numerical_df_train.query('SalePrice > 700000') # 692 , # 1182
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 691    692          60        104.0    21535           10            6
# 1182  1183          60        160.0    15623           10            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# 691        1994          1995      1170.0        1455  ...         382
# 1182       1996          1996         0.0        2096  ...         171
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# 691            50              0          0            0         0        0
# 1182           78              0          0            0       555        0
#
#       MoSold  YrSold  SalePrice
# 691        1    2007     755000
# 1182       7    2007     745000
#
# [2 rows x 38 columns]

# %% [markdown]
# attention :

# %%
df_test.query('BedroomAbvGr == 0') # So we have some testing data with 0 bedrooms
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1053  2514          20       RL        155.0    20064   Pave   NaN      IR1
# 1140  2601         120       RM         62.0     6710   Pave   NaN      IR1
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 1053         Low    AllPub  ...           0        0    NaN   NaN         NaN
# 1140         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition
# 1053       0      5    2007        WD         Normal
# 1140       0      6    2007        WD         Normal
#
# [2 rows x 80 columns]

# %% [markdown]
# BsmtFinSF1 - Check this out:

# %%
df_train.query('BsmtFinSF1 > 4000') # clearly 1299 is again an outlier
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
df_test.query('BsmtFinSF1 > 4000') # but in testing data we also have an outlier like this
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1089  2550          20       RL        128.0    39290   Pave   NaN      IR1
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 1089         Bnk    AllPub  ...           0        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition
# 1089   17000     10    2007       New        Partial
#
# [1 rows x 80 columns]

# %% [markdown]
# BsmtFinSF2

# %%
df_train.query('BsmtFinSF2 > 400 and SalePrice > 500000') # 441
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 440         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 440      4   2009        WD         Normal     555000
#
# [1 rows x 81 columns]

# %%
df_train.query('BsmtFinSF2 > 1250') # 323
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 322  323          60       RL         86.0    10380   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 322         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 322      8   2007        WD         Normal     301000
#
# [1 rows x 81 columns]

# %%
df_train.query('BsmtFinSF2 > 100 and SalePrice > 390000') # 662
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
# 661  662          60       RL         52.0    46589   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 440         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 661         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 440      4   2009        WD         Normal     555000
# 661      7   2009        WD         Normal     402000
#
# [2 rows x 81 columns]

# %% [markdown]
# BsmtFullBath

# %%
df_train.query('BsmtFullBath > 2') # 739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 738  739          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 738         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 738      3   2009        WD         Alloca     179000
#
# [1 rows x 81 columns]

# %%
df_test.query('BsmtFullBath > 2') # 1840
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 379  1840          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 379         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 379       0      3    2009        WD         Alloca
#
# [1 rows x 80 columns]

# %% [markdown]
# MSSubClass - started from here

# %%
df_train.query('SalePrice > 700000') # 692 1183 MSSubClass
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
#
# [2 rows x 81 columns]

# %%
df_train.query('OpenPorchSF > 450') # 496 584 1329 OpenPorchSF
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 583          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1328         Lvl    AllPub  ...        0    NaN  MnPrv        Shed    1150
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495      11   2009        WD        Abnorml      34900
# 583       7   2008        WD         Normal     325000
# 1328      6   2008        WD         Normal     256000
#
# [3 rows x 81 columns]

# %%
df_train.query('OverallCond == 1') # 379 376 OverallCond
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 375  376          30       RL          NaN    10020   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 375         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 375      3   2009        WD         Normal      61000
#
# [1 rows x 81 columns]

# %%
df_train.query('OverallQual == 8 and SalePrice > 500000') # 376 534 637 917 1101 458 770 # OverallQual
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 769  770          60       RL         47.0    53504   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 769         HLS    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 769      6   2010        WD         Normal     538000
#
# [1 rows x 81 columns]

# %%
df_train.query('PoolArea > 0') # 198 811 1171 1183 1299 1387 1424 PoolArea
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# ...

# %%
df_train.query('ScreenPorch > 300 and 400000< SalePrice < 500000') # 186 441 770 804 ScreenPorch
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 185         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 185      6   2006        WD         Normal     475000
#
# [1 rows x 81 columns]

# %%
df_train.query('TotalBsmtSF > 6000') # 1299 TotalBsmtSF
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
df_train.query('TotRmsAbvGrd == 5 and SalePrice > 350000') # 54 1182 636 534 TotRmsAbvGrd
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 53      54          20       RL         68.0    50271   Pave   NaN      IR1
# 1181  1182         120       RM         64.0     5587   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 53           Low    AllPub  ...        0    NaN   NaN         NaN       0
# 1181         HLS    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 53       11   2006        WD         Normal     385000
# 1181     11   2008       New        Partial     392500
#
# [2 rows x 81 columns]

# %%
df_train.query('WoodDeckSF > 350 and SalePrice > 600000') # 54 1170 WoodDeck
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1169      7   2006        WD         Normal     625000
#
# [2 rows x 81 columns]

# %%
df_train.query('YearBuilt < 1900 and SalePrice > 400000') # 186 YearBuild
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 185         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 185      6   2006        WD         Normal     475000
#
# [1 rows x 81 columns]

# %%
df_train.query('YearRemodAdd < 2000 and 600000 < SalePrice < 700000') # 314 1170 YearRemodAdd
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1169         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1169      7   2006        WD         Normal     625000
#
# [1 rows x 81 columns]

# %%
df_train.query('YrSold == 2010 and SalePrice > 500000') # 1047 1170 770 899 YrSold
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 769  770          60       RL         47.0    53504   Pave   NaN      IR2
# 898  899          20       RL        100.0    12919   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 769         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 898         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 769      6   2010        WD         Normal     538000
# 898      3   2010       New        Partial     611657
#
# [2 rows x 81 columns]

# %%
df_train.query('MiscVal > 2500') # 347 706 1231 MiscVal
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 346    347          20       RL          NaN    12772   Pave   NaN      IR1
# 705    706         190       RM         70.0     5600   Pave   NaN      Reg
# 1230  1231          90       RL          NaN    18890   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 346          Lvl    AllPub  ...        0    NaN   NaN        Gar2   15500
# 705          Lvl    AllPub  ...        0    NaN   NaN        Othr    3500
# 1230         Lvl    AllPub  ...        0    NaN   NaN        Gar2    8300
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 346       4   2007        WD         Normal     151500
# 705       7   2010        WD         Normal      55000
# 1230      8   2007        WD         Normal     190000
#
# [3 rows x 81 columns]

# %%
df_train.query('MoSold == 4 and SalePrice > 500000') # 692 804 899 441
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 440         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 440      4   2009        WD         Normal     555000
#
# [1 rows x 81 columns]

# %% [markdown]
# **Checking which outliers to remove**

# %%
# 1183 - SalePrice 745000
# 692 - SalePrice 755000
df_train.query('SalePrice > 700000')
# df_train.drop ([1183, 692])
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
#
# [2 rows x 81 columns]

# %%
# 198
df_train.query('PoolArea > 0')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# ...
